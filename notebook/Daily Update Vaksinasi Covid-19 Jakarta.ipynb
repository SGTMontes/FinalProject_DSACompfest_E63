# %% [markdown]
# # Daily Update Vaksinasi Covid-19 Data Analysis
#
# EDA atau Exploratory Analysis adalah proses pengeksplorasian data yang dilakukan untuk menemukan berbagai macam informasi yang mungkin saja belom diketahui pada suatu data. Pada proses ini juga dilakukan visualisasi terhadap data yang ingin digunakan
#
# Data yang digunakan adalah Daily Update Vaksinasi Covid-19. Pada data tersebut juga terdapat data harian kasus positif Indonesia dan juga Jakarta. Dengan adanya data ini, diharapkan dapat melihat kasus aktif covid-19 dengan vaksinasi yang sudah dilakukan oleh pemerintah Jakarta sehingga dapat ditemukan solusi yang harus di ambil untuk mengurangi penyebaran Covid-19 di Jakarta
#
# <b>CATATAN:</b> Data ini merupakan data Agregat Jakarta sehingga tidak menunjukan jumlah kasus positif dan vaksinasi untuk setiap Kelurahan/Kecamatan.

# %% [markdown]
# ## Loading the Data
#
# Pada step ini dimasukan file xlsx yang dibutuhkan yang sudah ada di drive

# %%
data_vaksinasi_jakarta = '/content/drive/MyDrive/finalProjectCompfest/Daily Update Data Vaksinasi Covid-19 Jakarta.xlsx'

# %% [markdown]
# ## Data Preparation and Celaning
# - Load the data using pandas
# - Look at some information about the data
# - Fix any errors or missing values from the data

# %%
import pandas as pd

# %% [markdown]
# ## Info dari data_vaksinasi

# %%
data_vaksinasi = pd.read_excel(data_vaksinasi_jakarta, sheet_name='Vaksinasi')

# %%
data_vaksinasi
# Out:
#        Tanggal  ...  Vaksinasi 2 Harian
# 0   2021-03-05  ...                 NaN
# 1   2021-03-06  ...                 NaN
# 2   2021-03-07  ...                 NaN
# 3   2021-03-08  ...                 NaN
# 4   2021-03-09  ...                 NaN
# ..         ...  ...                 ...
# 168 2021-08-20  ...            117829.0
# 169 2021-08-21  ...             83463.0
# 170 2021-08-22  ...             82364.0
# 171 2021-08-23  ...             34300.0
# 172 2021-08-24  ...             99016.0
#
# [173 rows x 23 columns]

# %%
data_vaksinasi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Tanggal                            173 non-null    datetime64[ns]
#  1   Target Vaksinasi Tenaga Kesehatan  173 non-null    int64
#  2   Vaksinasi 1 Tenaga Kesehatan       173 non-null    int64
#  3   Vaksinasi 2 Tenaga Kesehatan       173 non-null    int64
#  4   Persentase 1 Tenaga Kesehatan      173 non-null    float64
#  5   Persentase 2 Tenaga Kesehatan      173 non-null    float64
#  6   Target Vaksinasi Lansia            173 non-null    int64
#  7   Vaksinasi 1 Lansia                 173 non-null    int64
#  8   Vaksinasi 2 Lansia                 173 non-null    int64
#  9   Persentase 1 Lansia                173 non-null    float64
#  10  Persentase 2 Lansia                173 non-null    float64
#  11  Target Vaksinasi Pelayan Publik    173 non-null    int64
#  12  Vaksinasi 1 Pelayan Publik         173 non-null    int64
#  13  Vaksinasi 2 Pelayan Publik         173 non-null    int64
#  14  Persentase 1 Pelayan Publik        173 non-null    float64
#  15  Persentase 2 Pelayan Publik        173 non-null    float64
#  16  Target Vaksinasi Total             173 non-null    int64
#  17  Vaksinasi 1 Total                  173 non-null    int64
#  18  Vaksinasi 2 Total                  173 non-null    int64
#  19  Persentase 1 Total                 173 non-null    float64
#  20  Persentase 2 Total                 173 non-null    float64
#  21  Vaksinasi 1 Harian                 72 non-null     float64
#  22  Vaksinasi 2 Harian                 68 non-null     float64
# dtypes: datetime64[ns](1), float64(10), int64(12)
# memory usage: 31.2 KB

# %%
data_vaksinasi.describe()
# Out:
#        Target Vaksinasi Tenaga Kesehatan  ...  Vaksinasi 2 Harian
# count                              173.0  ...           68.000000
# mean                            112301.0  ...        45638.470588
# std                                  0.0  ...        55158.994605
# min                             112301.0  ...          210.000000
# 25%                             112301.0  ...         3903.250000
# 50%                             112301.0  ...        15069.000000
# 75%                             112301.0  ...        82857.000000
# max                             112301.0  ...       231568.000000
#
# [8 rows x 22 columns]

# %%
data_vaksinasi.isna().sum()
# Out:
# Tanggal                                0
# Target Vaksinasi Tenaga Kesehatan      0
# Vaksinasi 1 Tenaga Kesehatan           0
# Vaksinasi 2 Tenaga Kesehatan           0
# Persentase 1 Tenaga Kesehatan          0
# Persentase 2 Tenaga Kesehatan          0
# Target Vaksinasi Lansia                0
# Vaksinasi 1 Lansia                     0
# Vaksinasi 2 Lansia                     0
# Persentase 1 Lansia                    0
# Persentase 2 Lansia                    0
# Target Vaksinasi Pelayan Publik        0
# Vaksinasi 1 Pelayan Publik             0
# Vaksinasi 2 Pelayan Publik             0
# Persentase 1 Pelayan Publik            0
# Persentase 2 Pelayan Publik            0
# Target Vaksinasi Total                 0
# Vaksinasi 1 Total                      0
# Vaksinasi 2 Total                      0
# Persentase 1 Total                     0
# Persentase 2 Total                     0
# Vaksinasi 1 Harian                   101
# Vaksinasi 2 Harian                   105
# dtype: int64

# %% [markdown]
# # Exploratory Data And Visualization
#
# 1. Vaksinasi
# 2. Positif Aktif dan Total Positif
# 3. Positif Aktif, Sembuh, Vaksinasi

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_combined = pd.read_excel(data_vaksinasi_jakarta, sheet_name='Combined')

# %%
data_combined.head()
# Out:
#      Tanggal  Positif (Indonesia)  ...  Persentase 1 Total  Persentase 2 Total
# 0 2020-01-29                    0  ...                 NaN                 NaN
# 1 2020-03-01                    0  ...                 NaN                 NaN
# 2 2020-03-02                    2  ...                 NaN                 NaN
# 3 2020-03-03                    2  ...                 NaN                 NaN
# 4 2020-03-04                    2  ...                 NaN                 NaN
#
# [5 rows x 41 columns]

# %%
data_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Tanggal                            542 non-null    datetime64[ns]
#  1   Positif (Indonesia)                542 non-null    int64
#  2   Dirawat (Indonesia)                542 non-null    int64
#  3   Sembuh (Indonesia)                 542 non-null    int64
#  4   Meninggal (Indonesia)              542 non-null    int64
#  5   Meninggal (Jakarta)                542 non-null    int64
#  6   Sembuh (Jakarta)                   542 non-null    int64
#  7   Self-Isolation (Jakarta)           542 non-null    int64
#  8   Dirawat (Jakarta)                  542 non-null    int64
#  9   Positif (Jakarta)                  542 non-null    int64
#  10  Positif Aktif (Jakarta)            542 non-null    int64
#  11  Positif Harian (Indonesia)         542 non-null    int64
#  12  Dirawat Harian (Indonesia)         542 non-null    int64
#  13  Sembuh Harian (Indonesia)          542 non-null    int64
#  14  Meninggal Harian (Indonesia)       542 non-null    int64
#  15  Meninggal Harian (Jakarta)         542 non-null    int64
#  16  Sembuh Harian (Jakarta)            542 non-null    int64
#  17  Self-Isolation Harian (Jakarta)    542 non-null    int64
#  18  Dirawat Harian (Jakarta)           542 non-null    int64
#  19  Positif Harian (Jakarta)           542 non-null    int64
#  20  Positif Aktif Harian (Jakarta)     542 non-null    int64
#  21  Target Vaksinasi Tenaga Kesehatan  172 non-null    float64
#  22  Vaksinasi 1 Tenaga Kesehatan       172 non-null    float64
#  23  Vaksinasi 2 Tenaga Kesehatan       172 non-null    float64
#  24  Persentase 1 Tenaga Kesehatan      172 non-null    float64
#  25  Persentase 2 Tenaga Kesehatan      172 non-null    float64
#  26  Target Vaksinasi Lansia            172 non-null    float64
#  27  Vaksinasi 1 Lansia                 172 non-null    float64
#  28  Vaksinasi 2 Lansia                 172 non-null    float64
#  29  Persentase 1 Lansia                172 non-null    float64
#  30  Persentase 2 Lansia                172 non-null    float64
#  31  Target Vaksinasi Pelayan Publik    172 non-null    float64
#  32  Vaksinasi 1 Pelayan Publik         172 non-null    float64
#  33  Vaksinasi 2 Pelayan Publik         172 non-null    float64
#  34  Persentase 1 Pelayan Publik        172 non-null    float64
#  35  Persentase 2 Pelayan Publik        172 non-null    float64
#  36  Target Vaksinasi Total             172 non-null    float64
#  37  Vaksinasi 1 Total                  172 non-null    float64
#  38  Vaksinasi 2 Total                  172 non-null    float64
#  39  Persentase 1 Total                 172 non-null    float64
#  40  Persentase 2 Total                 172 non-null    float64
# dtypes: datetime64[ns](1), float64(20), int64(20)
# memory usage: 173.7 KB

# %%
tanggal = data_combined['Tanggal']
values = data_combined[['Positif Aktif (Jakarta)', 'Dirawat (Jakarta)', 'Self-Isolation (Jakarta)']]

plt.figure(figsize=(15,8))
plt.title("Kasus COVID-19 Jakarta")
plt.xlabel("Tanggal")
plt.plot(tanggal, values)
plt.grid()
plt.legend(values)

# %%
tanggal = data_combined['Tanggal'].loc[(data_combined['Tanggal'] >= '2020-10-01') & (data_combined['Tanggal'] <= '2021-02-28')]
values = data_combined[['Positif Aktif (Jakarta)', 'Dirawat (Jakarta)', 'Self-Isolation (Jakarta)']].loc[(data_combined['Tanggal'] >= '2020-10-01') & (data_combined['Tanggal'] <= '2021-02-28')]

plt.figure(figsize=(15,8))
plt.title("Kasus COVID-19 Jakarta Bulan Oktober 2020 - Februari 2021")
plt.xlabel("Tanggal")
plt.plot(tanggal, values)
plt.grid()
plt.legend(values)

# %%
tanggal = data_combined['Tanggal'].loc[(data_combined['Tanggal'] >= '2021-5-01')]
values = data_combined[['Positif Aktif (Jakarta)', 'Dirawat (Jakarta)', 'Self-Isolation (Jakarta)']].loc[(data_combined['Tanggal'] >= '2021-5-01')]

plt.figure(figsize=(15,8))
plt.title("Kasus COVID-19 Jakarta Bulan Mei 2021 - Agustus 2021")
plt.xlabel("Tanggal")
plt.plot(tanggal, values)
plt.grid()
plt.legend(values)

# %%
data_vaksinasi_wilayah = pd.read_excel(data_vaksinasi_jakarta, sheet_name='Vaksinasi Wilayah')

# %%
data_vaksinasi_wilayah.head()
# Out:
#      Kecamatan Kota / Kabupaten  ...  Keterangan.74  Cakupan Suntik 2.73
# 0       Cakung    Jakarta Timur  ...            NaN                  NaN
# 1   Cengkareng    Jakarta Barat  ...            NaN                  NaN
# 2   Kali Deres    Jakarta Barat  ...            NaN                  NaN
# 3    Cilincing    Jakarta Utara  ...            NaN                  NaN
# 4  Duren Sawit    Jakarta Timur  ...            NaN                  NaN
#
# [5 rows x 229 columns]

# %%
sns.set_theme(style='whitegrid')
fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

sns.barplot(y='Kota / Kabupaten', x='Cakupan Suntik 1 13 Jan - 11 Juni 2021', orient='h', data=data_vaksinasi_wilayah, ci=None, palette='Blues', ax=ax1)
sns.barplot(y='Kota / Kabupaten', x='Cakupan Suntik 2 13 Jan - 11 Juni 2021', data=data_vaksinasi_wilayah, orient='h', ci=None, palette='Blues', ax=ax2)

# %%
sns.set_theme(style='whitegrid')
sns.barplot(y='Kota / Kabupaten', x='Cakupan Suntik 2 13 Jan - 11 Juni 2021', data=data_vaksinasi_wilayah, orient='h', ci=None, palette='Blues')

# %%
tanggal = data_combined['Tanggal'].loc[(data_combined['Tanggal'] >= '2021-1-13') & (data_combined['Tanggal'] <= '2021-6-11')]
values = data_combined[['Positif Aktif (Jakarta)', 'Dirawat (Jakarta)', 'Self-Isolation (Jakarta)']].loc[(data_combined['Tanggal'] >= '2021-1-13') & (data_combined['Tanggal'] <= '2021-6-11')]
plt.figure(figsize=(15,8))
plt.title("Kasus COVID-19 Jakarta Bulan 13 Jan 2021 - 11 Juni 2021")
plt.xlabel("Tanggal")
plt.plot(tanggal, values)
plt.grid()
plt.legend(values)

# %%
tanggal = data_combined['Tanggal'].loc[(data_combined['Tanggal'] >= '2021-1-13') & (data_combined['Tanggal'] <= '2021-6-11')]
values = data_combined[['Vaksinasi 1 Total', 'Vaksinasi 2 Total']].loc[(data_combined['Tanggal'] >= '2021-1-13') & (data_combined['Tanggal'] <= '2021-6-11')]
plt.figure(figsize=(15,8))
plt.title("Kasus COVID-19 Jakarta Bulan Mei 2021 - Agustus 2021")
plt.xlabel("Tanggal")
plt.plot(tanggal, values)
plt.grid()
plt.legend(values)

# %%
df_kepadatan_penduduk = pd.read_excel('/content/drive/MyDrive/finalProjectCompfest/Penduduk, Laju Pertumbuhan Penduduk, Distribusi Persentase Penduduk Kepadatan Penduduk, Rasio Jenis Kelamin Penduduk Menurut Provinsi_Kabupaten_Kota.xlsx')

# %%
df_kepadatan_penduduk
# Out:
#           Kab/Kota  ...  Rasio Jenis Kelamin Penduduk 2020
# 0       Kep Seribu  ...                                103
# 1  Jakarta Selatan  ...                                102
# 2    Jakarta Timur  ...                                101
# 3    Jakarta Pusat  ...                                104
# 4    Jakarta Barat  ...                                102
# 5    Jakarta Utara  ...                                103
# 6      DKI Jakarta  ...                                102
#
# [7 rows x 16 columns]

# %%
df_kepadatan_penduduk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Kab/Kota                                  7 non-null      object
#  1   Jumlah Penduduk 2018                      7 non-null      int64
#  2   Jumlah Penduduk 2019                      7 non-null      int64
#  3   Jumlah Penduduk 2020                      7 non-null      int64
#  4   Laju Pertumbuhan Penduduk per Tahun 2018  7 non-null      int64
#  5   Laju Pertumbuhan Penduduk per Tahun 2019  7 non-null      int64
#  6   Laju Pertumbuhan Penduduk per Tahun 2020  7 non-null      int64
#  7   Persentase Penduduk 2018                  7 non-null      int64
#  8   Persentase Penduduk 2019                  7 non-null      int64
#  9   Persentase Penduduk 2020                  7 non-null      int64
#  10  Kepadatan Penduduk per km2 2018           7 non-null      int64
#  11  Kepadatan Penduduk per km2 2019           7 non-null      int64
#  12  Kepadatan Penduduk per km2 2020           7 non-null      int64
#  13  Rasio Jenis Kelamin Penduduk 2018         7 non-null      int64
#  14  Rasio Jenis Kelamin Penduduk 2019         7 non-null      int64
#  15  Rasio Jenis Kelamin Penduduk 2020         7 non-null      int64
# dtypes: int64(15), object(1)
# memory usage: 1.0+ KB

# %%
sns.set_theme(style='whitegrid')
sns.barplot(y='Kab/Kota', x='Kepadatan Penduduk per km2 2020', data=df_kepadatan_penduduk , orient='h', ci=None, palette='Greens')

# %% [markdown]
# # Ask and Aswer Question
#
# 1. Bagaiamana bentuk grafik antara vaksinasi dengan tingkat positif dan sembuh di JKT?
# 2. Apakah dengan banyaknya vaksinasi kasus positif akan berkurang?
# 3. Apakah dengan banyaknya vaksinasi tingkat pasien covid-19 sembuh akan bertambah?
